# %%
# Dependencies
import requests
import pandas as pd

# %%
# Import U.S. Census API Key
from config import api_key
if api_key == "YOUR KEY HERE":
    print("Please edit your config.py file.")

# %%
#Testing

# %%
#Param dictionary
#TO DO!!
params = {
    #"get": "TEHC_ST,EJB1_CLWRK,EJB1_PVWKTR9,EJB1_DYSWKDH,EJB1_NETGRO1,TVAL_HOME",
    "get": "TEHC_ST",
    "for": "state:*",
    "key": api_key
}
base_url = "https://api.census.gov/data/2022/sipp?"

# %%
#TO DO Continued
response = requests.get(base_url, params=params).json()
#response = requests.get(base_url, params=params)
print(response)
#new_list = [x[0] for x in response]
#set(new_list)
#print(response)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
#Single API Call
url = f"https://api.census.gov/data/2022/sipp?get={var_call}&key={api_key}"
response = requests.get(url)
response = response.json()
new_list = [x[0] for x in response]
set(new_list)

# %%
#Single API Call
url = f"https://api.census.gov/data/2022/sipp?get=SSUID&key={api_key}"
response = requests.get(url)
response = response.json()
new_list = [x[0] for x in response]
set(new_list)
# Out:
# {'66719934229420',
#  '33241817208622',
#  '03886013608921',
#  '71786028568822',
#  '00041821531620',
#  '88128540388322',
#  '88199593282821',
#  '39811496748022',
#  '33286082851820',
#  '00086041596421',
#  '71786078355421',
#  '88141868919622',
#  '88186068912520',
#  '33241881600922',
#  '88128520406922',
#  '00041882888722',
#  '87628533477222',
#  '03886013546721',
#  '66741828534322',
#  '66786060675522',
#  '88128512673022',
#  '29286055272020',
#  '88128566289922',
#  '88186096726821',
#  '46986019965522',
#  '33241808694422',
#  '39841810139221',
#  '83711409273722',
#  '46986058863222',
#  '39828561052122',
#  '39886030264320',
#  '00086013556821',
#  '03841804969120',
#  '46986078385522',
#  '88186050822920',
#  '46909240343422',
#  '87641805700321',
#  '68592560931022',
#  '88186084718321',
#  '66728511425921',
#  '46913690870722',
#  '39881660625820',
#  '87686081650120',
#  '87686008652222',
#  '66741820973822',
#  '66734281608622',
#  '03886058829422',
# ...
